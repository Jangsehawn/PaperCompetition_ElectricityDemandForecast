# %%
import os
os.getcwd()
os.chdir("C:/Users/임대현/Downloads/학습컨텐츠/thesis/dataset")

# %%
import pandas as pd

# %%
sub2015 = pd.read_excel("2015.xlsx", sheet_name="2015년")

# %%
sub2015
# Out:
#                 날짜   역번호         역명  구분  05~06  06~07  07~08  08~09  09~10  \
# 0       2015-01-01   150   서울역(150)  승차    441    399    572   1106   1474
# 1       2015-01-01   151    시청(151)  승차    101     95    104    127    233
# 2       2015-01-01   152    종각(152)  승차    898    482    281    291    328
# 3       2015-01-01   153  종로3가(153)  승차    371    212    155    189    347
# 4       2015-01-01   154  종로5가(154)  승차     57    101     83    128    209
# ...            ...   ...        ...  ..    ...    ...    ...    ...    ...
# 200745  2015-12-31  2823     남한산성입구  하차     60    162    417    952    491
# 200746  2015-12-31  2824      단대오거리  하차     48    207    432    804    386
# 200747  2015-12-31  2825         신흥  하차     26     73    103    230    233
# 200748  2015-12-31  2826         수진  하차     38     67    115    326    211
# 200749  2015-12-31  2827      모란(8)  하차     60     84    138    283    150
#
# ...

# %%
sub2016 = pd.read_excel("2016.xlsx",sheet_name="2016년")

# %%
sub2016
# Out:
#                 날짜   월   역번호        역명  구분  05~06  06~07  07~08  08~09  09~10  \
# 0       2016-01-01   1   150  서울역(150)  승차    469    339    584   1144   1723
# 1       2016-01-01   1   150  서울역(150)  하차    342   1637   1753   1856   2438
# 2       2016-01-01   1   151   시청(151)  승차    103    127    110    191    298
# 3       2016-01-01   1   151   시청(151)  하차     68    306    554    939    689
# 4       2016-01-01   1   152   종각(152)  승차    702    341    234    296    335
# ...            ...  ..   ...       ...  ..    ...    ...    ...    ...    ...
# 201295  2016-12-31  12  2825        신흥  하차     23     62     77    114    223
# 201296  2016-12-31  12  2826        수진  승차     85    119    202    291    327
# 201297  2016-12-31  12  2826        수진  하차     37     71     62    137    148
# 201298  2016-12-31  12  2827     모란(8)  승차     45     57    115    155    152
# 201299  2016-12-31  12  2827     모란(8)  하차    114     56     73    104    134
#
# ...

# %%
sub20171 = pd.read_excel("2017_1.xlsx", sheet_name = "2017년 1~5월")

# %%
sub20171
# Out:
#                날짜  월   역번호        역명  구분  05~06  06~07  07~08  08~09  09~10  \
# 0      2017-01-01  1   150  서울역(150)  승차    470    286    397    786   1421
# 1      2017-01-01  1   150  서울역(150)  하차    278    880    859    964   1407
# 2      2017-01-01  1   151   시청(151)  승차    204    105    112    162    288
# 3      2017-01-01  1   151   시청(151)  하차     73    203    314    483    669
# 4      2017-01-01  1   152   종각(152)  승차    791    390    245    270    323
# ...           ... ..   ...       ...  ..    ...    ...    ...    ...    ...
# 83045  2017-05-31  5  2825        신흥  하차     10     77    116    264    181
# 83046  2017-05-31  5  2826        수진  승차    155    247    661    828    398
# 83047  2017-05-31  5  2826        수진  하차     24     99    263    535    296
# 83048  2017-05-31  5  2827     모란(8)  승차     82    111    452    503    256
# 83049  2017-05-31  5  2827     모란(8)  하차     20    112    244    466    205
#
# ...

# %%
sub20172 = pd.read_excel("2017_2.xlsx", sheet_name = "2017년 6~12월")

# %%
sub20172
# Out:
#                  2017-06-01   6   150  서울역(150)  승차  381   579  1624   2619  \
# 0                2017-06-01   6   150  서울역(150)  하차  273  2023  4819  10126
# 1                2017-06-01   6   151   시청(151)  승차   75   153   287    397
# 2                2017-06-01   6   151   시청(151)  하차  177   923  3561   8231
# 3                2017-06-01   6   152   종각(152)  승차  132   177   386    571
# 4                2017-06-01   6   152   종각(152)  하차  195  1253  5034  13025
# ...                     ...  ..   ...       ...  ..  ...   ...   ...    ...
# 117694  2017-12-31 00:00:00  12  2825        신흥  하차    9    49    38     53
# 117695  2017-12-31 00:00:00  12  2826        수진  승차   42    76   130    216
# 117696  2017-12-31 00:00:00  12  2826        수진  하차    8    68    76     88
# 117697  2017-12-31 00:00:00  12  2827        모란  승차   29    36    74     87
# 117698  2017-12-31 00:00:00  12  2827        모란  하차    5    55    36     50
#
# ...

# %%
sub2018 = pd.read_excel("2018.xlsx", sheet_name = "2018년 역별 시간대별 이용인원")

# %%
sub2018
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        날짜         구분         호선        역번호         역명
# 1       2018-01-01 00:00:00          휴        1호선        150        서울역
# 2       2018-01-01 00:00:00          휴        1호선        150        서울역
# 3       2018-01-01 00:00:00          휴        1호선        151         시청
# 4       2018-01-01 00:00:00          휴        1호선        151         시청
# ...                     ...        ...        ...        ...        ...
# 200746  2018-12-31 00:00:00          평        8호선       2825         신흥
# 200747  2018-12-31 00:00:00          평        8호선       2826         수진
# 200748  2018-12-31 00:00:00          평        8호선       2826         수진
# 200749  2018-12-31 00:00:00          평        8호선       2827         모란
# 200750  2018-12-31 00:00:00          평        8호선       2827         모란
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
sub2019 = pd.read_excel("2019.xlsx", sheet_name = "2019년 1~12월 역별 시간대별 이용인원")

# %%
sub2019
# Out:
#                  Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                        날짜         호선        역번호         역명         구분
# 1       2019-01-01 00:00:00        1호선        150        서울역         승차
# 2       2019-01-01 00:00:00        1호선        150        서울역         하차
# 3       2019-01-01 00:00:00        1호선        151         시청         승차
# 4       2019-01-01 00:00:00        1호선        151         시청         하차
# ...                     ...        ...        ...        ...        ...
# 200800  2019-12-31 00:00:00        8호선       2825         신흥         하차
# 200801  2019-12-31 00:00:00        8호선       2826         수진         승차
# 200802  2019-12-31 00:00:00        8호선       2826         수진         하차
# 200803  2019-12-31 00:00:00        8호선       2827         모란         승차
# 200804  2019-12-31 00:00:00        8호선       2827         모란         하차
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
sub2020 = pd.read_excel("2020.xlsx", sheet_name = "역별 시간대별 이용인원 상단리스트 (34)")

# %%
sub2020
# Out:
#               날짜   호선   역번호   역명  구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 0     2020-01-01  1호선   150  서울역  승차     356      280      313      774
# 1     2020-01-01  1호선   150  서울역  하차     235      952      828     1043
# 2     2020-01-01  1호선   151   시청  승차     105      118      123      206
# 3     2020-01-01  1호선   151   시청  하차      81      223      334      570
# 4     2020-01-01  1호선   152   종각  승차     798      366      198      236
# ...          ...  ...   ...  ...  ..     ...      ...      ...      ...
# 66675 2020-04-30  8호선  2825   신흥  하차      21       69       59       70
# 66676 2020-04-30  8호선  2826   수진  승차      89      118      164      254
# 66677 2020-04-30  8호선  2826   수진  하차      12       64       44       69
# 66678 2020-04-30  8호선  2827   모란  승차      57       53      101      142
# 66679 2020-04-30  8호선  2827   모란  하차      19       76       50      104
#
#        09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  \
# ...

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
# %matplotlib inline

# %%
plt.title("Plot")
plt.plot(pd.DataFrame(sub2020).iloc[[1,551,1101,1651,2203,2753,3305,3857,4409,4961,
                               5513,6067,6617,7171,7721,8273,8825,9375,9927,10477,
                               11027,11579,12131,12681,13231,13781,14331,14881,15431,15983,16537,
                               17087,17639,18193,18743,19295,19847,20401,20951,21503,22053,
                               22605,23155,23705,24257,24809,25359,25911,26461,27015,27567,
                               28119,28671,29221,29771,30323,30875,31427,31979,32531,
                               33081,33631,34185,34735,35285,35837,36387,36937,37487,38041,
                               38591,39143,39693,40243,40793,41343,41895,42447,42997,43551,
                               44013,44653,45203,45755,46305,46855,47405,47955,48505,49055,49605,
                               50155,50707,51259,51811,52631,52911,53641,54013,54565,55115,
                               55667,56217,56769,57319,57871,58421,58973,59523,60073,60623,
                               61173,61725,62275,62825,63377,63927,64479,65029,65581,66131],[25]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-9d3d9fb2482b> in <module>
#      13                                61173,61725,62275,62825,63377,63927,64479,65029,65581,66131],[25]])
#      14 plt.show()
# ---> 15 df2.iloc[[1,2,4],[0,2]]
#
# NameError: name 'df2' is not defined

# %%
pd.DataFrame(sub2020)[1,551,1101,1651,2203,2753,3305,3857,4409,4961,
                      5513,6067,6617,7171,7721,8273,8825,9375,9927,10477,
                      11027,11579,12131,12681,13231,13781,14331,14881,15431,15983,16537,
                      17087,17639,18193,18743,19295,19847,20401,20951,21503,22053,
                      22605,23155,23705,24257,24809,25359,25911,26461,27015,27567,
                      28119,28671,29221,29771,30323,30875,31427,31979,32531,
                      33081,33631,34185,34735,35285,35837,36387,36937,37487,38041,
                    8591,39143,39693,40243,40793,41343,41895,42447,42997,43551,
                               44013,44653,45203,45755,46305,46855,47405,47955,48505,49055,49605,
                               50155,50707,51259,51811,52631,52911,53641,54013,54565,55115,
                               55667,56217,56769,57319,57871,58421,58973,59523,60073,60623,
                               61173,61725,62275,62825,63377,63927,64479,65029,65581,66131:]["합계"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-e0ecfd773b30> in <module>
#       7                                50155,50707,51259,51811,52631,52911,53641,54013,54565,55115,
#       8                                55667,56217,56769,57319,57871,58421,58973,59523,60073,60623,
# ----> 9                                61173,61725,62275,62825,63377,63927,64479,65029,65581,66131:]["합계"]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
# ...

# %%
sub2020[1:4,"구분"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-52e1335091ad> in <module>
# ----> 1 sub2020[1:4,"구분"]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
pd.DataFrame(sub2020)[0,1,4]["합계"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 1, 4)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-39a968f1b990> in <module>
# ----> 1 pd.DataFrame(sub2020)[0,1,4]["합계"]
#
# ...

# %%
dates = pd.date_range('20200101', periods=121)

# %%
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24',
#                '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28',
#                '2020-04-29', '2020-04-30'],
#               dtype='datetime64[ns]', length=121, freq='D')

# %%
sub20202=pd.DataFrame(sub2020,index=dates)
sub20202
# Out:
#             날짜   호선  역번호   역명   구분  06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  \
# 2020-01-01 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-01-02 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-01-03 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-01-04 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-01-05 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# ...         ..  ...  ...  ...  ...     ...      ...      ...      ...
# 2020-04-26 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-04-27 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-04-28 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-04-29 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
# 2020-04-30 NaT  NaN  NaN  NaN  NaN     NaN      NaN      NaN      NaN
#
#             09 ~ 10  ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  \
# ...

# %%
# Out:
# 1        30085
# 2        12212
# 3        10608
# 4        20523
# 5        16401
#          ...
# 66675     3162
# 66676     3123
# 66677     2684
# 66678     2956
# 66679     2496
# Name: 합계, Length: 66679, dtype: int64

# %%
a = list()

# %%
a.append([1,551,1101,1651,2203,2753,3305,3857,4409,4961,
                               5513,6067,6617,7171,7721,8273,8825,9375,9927,10477,
                               11027,11579,12131,12681,13231,13781,14331,14881,15431,15983,16537,
                               17087,17639,18193,18743,19295,19847,20401,20951,21503,22053,
                               22605,23155,23705,24257,24809,25359,25911,26461,27015,27567,
                               28119,28671,29221,29771,30323,30875,31427,31979,32531,
                               33081,33631,34185,34735,35285,35837,36387,36937,37487,38041,
                               38591,39143,39693,40243,40793,41343,41895,42447,42997,43551,
                               44013,44653,45203,45755,46305,46855,47405,47955,48505,49055,49605,
                               50155,50707,51259,51811,52631,52911,53641,54013,54565,55115,
                               55667,56217,56769,57319,57871,58421,58973,59523,60073,60623,
                               61173,61725,62275,62825,63377,63927,64479,65029,65581,66131])

# %%
a
# Out:
# [[1,
#   551,
#   1101,
#   1651,
#   2203,
#   2753,
#   3305,
#   3857,
#   4409,
#   4961,
#   5513,
#   6067,
#   6617,
#   7171,
#   7721,
#   8273,
#   8825,
#   9375,
#   9927,
#   10477,
#   11027,
#   11579,
#   12131,
#   12681,
#   13231,
#   13781,
#   14331,
#   14881,
#   15431,
#   15983,
#   16537,
#   17087,
#   17639,
#   18193,
#   18743,
#   19295,
#   19847,
#   20401,
#   20951,
#   21503,
#   22053,
#   22605,
#   23155,
#   23705,
#   24257,
#   24809,
#   25359,
#   25911,
#   26461,
#   27015,
#   27567,
#   28119,
#   28671,
#   29221,
#   29771,
#   30323,
#   30875,
#   31427,
#   31979,
#   32531,
#   33081,
#   33631,
#   34185,
#   34735,
#   35285,
#   35837,
#   36387,
#   36937,
#   37487,
#   38041,
#   38591,
#   39143,
#   39693,
#   40243,
#   40793,
#   41343,
#   41895,
#   42447,
#   42997,
#   43551,
#   44013,
#   44653,
#   45203,
#   45755,
#   46305,
#   46855,
#   47405,
#   47955,
#   48505,
#   49055,
#   49605,
#   50155,
#   50707,
# ...

# %%
a2 = list()
for i in range(0,121):
    a2.append(a[0][i]+1)

# %%
a3 = list()
for i in range(0,121):
    a3.append(a[0][i]+2)

# %%
a230 = list()
for i in range(0,121):
    a230.append(a[0][i]+229)

# %%
plt.title("Plot")
plt.plot(pd.DataFrame(sub2020).iloc[a230,[25]])
plt.show()
